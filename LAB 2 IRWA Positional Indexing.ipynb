# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/IRWA LAB 2
# Out:
# /content/drive/MyDrive/IRWA LAB 2

# %%
import os 
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

for doc_no in range(1,4):
     #Document no from 1 to 4
     with open(os.getcwd()+'/positional/doc_'+str(doc_no)+'.txt','r') as file:
       print(file.read())
       s=file.read().replace('\n','')[1:]
       print(s)

       s=re.sub('','',s)
       s = re.sub(r"won\'t", "will not",s) 
       s = re.sub(r"can\'t", "can not",s) 
       s = re.sub(r"n\'t", " not",s) 
       s = re.sub(r"\'s", "is",s) 
       s = re.sub(r"\'d", "would",s) 
       s = re.sub(r"\'ll'", "will",s) 
       s = re.sub(r"\'t", "not",s) 
       s = re.sub(r"\'ve", "have",s) 
       s = re.sub(r"\'m", "am",s) 
       s = re.sub(r'[^\w\s]', ' ',s) #convert short term to long term 

      # print(s)

words = word_tokenize(str(s).lower())
print('Tokenized_sentence',sentences)


#removal of stopwords 

stop_words=stopwords.words('english')

new_sentence = [word for word in words if word not in stop_words] 
print(new_sentence)

#stemming
# Out:
# ﻿Remarks circus Announcing Candidacy for President in New York City
# ...

# %% [markdown]
# IR part

# %%
# Out:
# Tokenized_sentence []
# []

# %%
import nltk
nltk.download('punkt')

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True
